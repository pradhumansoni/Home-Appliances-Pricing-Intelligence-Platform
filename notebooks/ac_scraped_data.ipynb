# %%
with open('D:/Study/data_science/underpriced-listing-predictor/scraper/smartprix.html','r' , encoding='utf-8') as f:
    ac_html = f.read()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(ac_html , 'lxml')

# %%
len(soup.find_all('div' , {'class':'sm-product has-tag has-features has-actions'}))
# Out:
# 1020
